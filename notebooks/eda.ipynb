# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_parquet("../data/sample.parquet")
df.head(100)
# Out:
#         fw   mver   lts           dst_name   af           dst_addr  \
# 0   5090.0  2.6.4  54.0               None  NaN               None
# 1   5090.0  2.6.4  54.0               None  NaN               None
# 2   5090.0  2.6.4  54.0               None  NaN               None
# 3   5090.0  2.6.4  54.0               None  NaN               None
# 4   5090.0  2.6.4  54.0               None  NaN               None
# ..     ...    ...   ...                ...  ...                ...
# 95  5090.0  2.6.4  62.0               None  NaN               None
# 96  5090.0  2.6.4  62.0               None  NaN               None
# 97  5090.0  2.6.4  65.0  2a00:1398:8:2::10  6.0  2a00:1398:8:2::10
# 98  5090.0  2.6.4  45.0       212.202.68.1  4.0       212.202.68.1
# 99  5090.0  2.6.4  35.0     156.154.85.254  4.0     156.154.85.254
#
#                   src_addr proto  ttl  size  ...  min_value  max_value  \
# 0                     None  None  NaN   NaN  ...        NaN        NaN
# ...

# %%
df.columns.tolist()
# Out:
# ['fw',
#  'mver',
#  'lts',
#  'dst_name',
#  'af',
#  'dst_addr',
#  'src_addr',
#  'proto',
#  'ttl',
#  'size',
#  'dup',
#  'rcvd',
#  'sent',
#  'min_value',
#  'max_value',
#  'avg_value',
#  'msm_id',
#  'prb_id',
#  'event_timestamp',
#  'msm_name',
#  'src_public_ip',
#  'measurement_type',
#  'step']

# %%
df.head().T
# Out:
#                                       0                      1  \
# fw                               5090.0                 5090.0
# mver                              2.6.4                  2.6.4
# lts                                54.0                   54.0
# dst_name                           None                   None
# af                                  NaN                    NaN
# dst_addr                           None                   None
# src_addr                           None                   None
# proto                              None                   None
# ttl                                 NaN                    NaN
# size                                NaN                    NaN
# dup                                 NaN                    NaN
# rcvd                                NaN                    NaN
# sent                                NaN                    NaN
# min_value                           NaN                    NaN
# ...
